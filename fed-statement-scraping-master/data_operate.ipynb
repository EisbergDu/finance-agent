# %%
import pandas as pd
raw_data = pd.read_csv('/Users/ad/Desktop/financeagent/fed-statement-scraping-master/communications.csv')

# %%
raw_data
# Out:
#            Date Release Date       Type  \
# 0    2025-10-29   2025-10-29  Statement
# 1    2025-09-17   2025-09-17  Statement
# 2    2025-09-17   2025-10-08     Minute
# 3    2025-07-30   2025-07-30  Statement
# 4    2025-07-30   2025-08-20     Minute
# ..          ...          ...        ...
# 450  2000-05-16   2000-05-16  Statement
# 451  2000-03-21   2000-05-18     Minute
# 452  2000-03-21   2000-03-21  Statement
# 453  2000-02-02   2000-03-23     Minute
# 454  2000-02-02   2000-02-02  Statement
#
#                                                   Text
# 0    Available indicators suggest that economic act...
# 1    Recent indicators suggest that growth of econo...
# 2    Minutes of the Federal Open Market Committee\n...
# 3    Although swings in net exports continue to aff...
# 4    Minutes of the Federal Open Market Committee\n...
# ..                                                 ...
# 450  The Federal Open Market Committee voted today ...
# ...
